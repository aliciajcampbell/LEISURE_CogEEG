# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme('notebook')
from scipy import stats

df = pd.read_excel('demo_attention_EC_T1_Main.xlsx')

sart_cols= ['Total GO','Total NO-GO','Correct GO','Correct NO-GO','Incorrect GO','Incorrect NO-GO','Average RT (Correct GO)','Average RT (Incorrect NO-GO)','SD RT (Correct GO)','SD RT (Incorrect NO-GO)','Median RT (Correct GO)','Median RT (Incorrect NO-GO)','Minimum RT (Correct GO)','Minimum RT (Incorrect NO-GO)','Maximum RT (Correct GO)','Maximum RT (Incorrect NO-GO)']

# %%
df[sart_cols].describe()
# Out:
#        Total GO  Total NO-GO  Correct GO  Correct NO-GO  Incorrect GO  \
# count      97.0         97.0   97.000000      97.000000     97.000000
# mean      480.0         60.0  478.257732      50.020619      1.742268
# std         0.0          0.0    2.923605       6.474275      2.923605
# min       480.0         60.0  468.000000      32.000000      0.000000
# 25%       480.0         60.0  478.000000      47.000000      0.000000
# 50%       480.0         60.0  479.000000      51.000000      1.000000
# 75%       480.0         60.0  480.000000      55.000000      2.000000
# max       480.0         60.0  480.000000      60.000000     12.000000
#
#        Incorrect NO-GO  Average RT (Correct GO)  Average RT (Incorrect NO-GO)  \
# count        97.000000                97.000000                     97.000000
# mean          9.979381                 0.465455                      0.362501
# std           6.474275                 0.068308                      0.082308
# min           0.000000                 0.334981                      0.000000
# 25%           5.000000                 0.416986                      0.331055
# 50%           9.000000                 0.456689                      0.359180
# 75%          13.000000                 0.506213                      0.392090
# max          28.000000                 0.657536                      0.731201
#
#        SD RT (Correct GO)  SD RT (Incorrect NO-GO)  Median RT (Correct GO)  \
# count           97.000000                97.000000               97.000000
# mean             0.106383                 0.054105                0.449350
# std              0.027211                 0.085992                0.070813
# min              0.052371                 0.000000                0.322754
# 25%              0.089110                 0.027223                0.395020
# 50%              0.101082                 0.036140                0.433105
# 75%              0.126098                 0.045226                0.491211
# max              0.180239                 0.614035                0.669922
#
#        Median RT (Incorrect NO-GO)  Minimum RT (Correct GO)  \
# count                    97.000000                97.000000
# mean                      0.350229                 0.255557
# std                       0.065277                 0.057765
# min                       0.000000                 0.063477
# 25%                       0.325195                 0.233398
# 50%                       0.355469                 0.259766
# 75%                       0.385254                 0.290039
# max                       0.467773                 0.379883
#
#        Minimum RT (Incorrect NO-GO)  Maximum RT (Correct GO)  \
# count                     97.000000                97.000000
# mean                       0.301587                 1.063215
# std                        0.063493                 0.288148
# min                        0.000000                 0.606445
# 25%                        0.271484                 0.834961
# 50%                        0.299805                 0.998047
# 75%                        0.331055                 1.237305
# max                        0.453125                 1.885742
#
#        Maximum RT (Incorrect NO-GO)
# count                     97.000000
# mean                       0.474569
# std                        0.255964
# min                        0.000000
# 25%                        0.393555
# 50%                        0.425781
# 75%                        0.455078
# max                        1.793945

# %%
# Calculating Hit Rate and False Alarm Rate
df['Hit rate'] = df['Correct GO'] / df['Total GO']
df['False Alarm rate'] = df['Incorrect NO-GO'] / df['Total NO-GO']

# Adjusting for Extreme Values with Log-linear Correction (Half-item Correction)
df['Adjusted Hit rate'] = (df['Correct GO'] + 0.5) / (df['Total GO'] + 1)
df['Adjusted False Alarm rate'] = (df['Incorrect NO-GO'] + 0.5) / (df['Total NO-GO'] + 1)

# Z Transformation
df['z - Hit rate'] = stats.norm.ppf(df['Adjusted Hit rate'])
df['z - False Alarm rate'] = stats.norm.ppf(df['Adjusted False Alarm rate'])

# Calculate d'
df['D prime'] = df['z - Hit rate'] - df['z - False Alarm rate']

# Calculate criterion
df['Criterion'] = -0.5 * (df['z - Hit rate'] + df['z - False Alarm rate'])
